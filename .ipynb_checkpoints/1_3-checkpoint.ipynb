# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import math

# %%
def GBM_exact(T, K, S, sigma, r, M):
    S_all = []
    S_all.append(S)
    dt = T/M
    Z_all = []
    for i in range(M-1):
        Zm = np.random.normal()
        Z_all.append(Zm)
        S_all.append(S_all[i] * np.exp((r-0.5*sigma**2) * dt + sigma * np.sqrt(dt) * Zm)) 
    return S_all, Z_all

# %%
def GBM_Euler(T, K, S, sigma, r, M, Z_all = None):
    S_all = []
    S_all.append(S)
    dt = T/M
    for i in range(M-1):
        if Z_all:
            Zm = Z_all[i]
        else:
            Zm = np.random.normal()
        S_all.append(S_all[i] + r* S_all[i] * dt + sigma * S_all[i] * np.sqrt(dt) * Zm) 
    return S_all

# %%
T = 1
K = 99
S = 100
sigma = 0.2
r = 0.06

# %%
M=52
s_all = [GBM_Euler(T, K, S, sigma, r, M) for x in range(1000)]
s_all_exact = [GBM_exact(T, K, S, sigma, r, M)[0] for x in range(1000)]

# %%
arrays = [np.array(x) for x in s_all]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
arrays = [np.array(x) for x in s_all_exact]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
s_all_exact, Z_all = GBM_exact(T, K, S, sigma, r, M)
s_all = GBM_Euler(T, K, S, sigma, r, M, Z_all)

# %%
plt.plot(s_all_exact)

# %%
plt.plot(s_all)

# %%
def get_delta(S, K, r, sigma, tau):
    d1 = (math.log(S/K) + (r + 0.5 * sigma**2) * tau) / (sigma * math.sqrt(tau))
    return norm.cdf(d1)

def adjust_hedge(portfolio, delta):
    if portfolio['delta'] < delta:
        # buy more stock
    elif portfolio['delta'] > delta:
        # sell stock

def simulate_hedge(T, K, S, sigma, delta_sigma, r, M, Z_all = None):
    # setup
    S_all = []
    S_all.append(S)
    dt = T/M
    tau = 0
    # riskfree portfolio for a call option sells the call and buys the stock, right?
    portfolio = {}
    portfolio['delta'] = get_delta(S, K, r, delta_sigma, tau)
    portfolio['call'] = -1
    
    
    # run the hedging simulation
    for i in range(M-1):
        if Z_all:
            Zm = Z_all[i]
        else:
            Zm = np.random.normal()
        S_all.append(S_all[i] * np.exp((r-0.5*sigma**2) * dt + sigma * np.sqrt(dt) * Zm)) 
        tau += dt
        
        delta = get_delta(S_all[-1], K, r, sigma, tau)
        adjust_hedge(portfolio, delta)
    return S_all

# %%
get_delta(108, 99, 0.06, 0.2, 0.8)
# Out:
# 0.8007153790950352
