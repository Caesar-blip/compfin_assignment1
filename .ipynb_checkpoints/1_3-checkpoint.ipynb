# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import math

# %%
def GBM_exact(T, K, S, sigma, r, M):
    S_all = []
    S_all.append(S)
    dt = T/M
    Z_all = []
    for i in range(M-1):
        Zm = np.random.normal()
        Z_all.append(Zm)
        S_all.append(S_all[i] * np.exp((r-0.5*sigma**2) * dt + sigma * np.sqrt(dt) * Zm)) 
    return S_all, Z_all

# %%
def GBM_Euler(T, K, S, sigma, r, M, Z_all = None):
    S_all = []
    S_all.append(S)
    dt = T/M
    for i in range(M-1):
        if Z_all:
            Zm = Z_all[i]
        else:
            Zm = np.random.normal()
        S_all.append(S_all[i] + r* S_all[i] * dt + sigma * S_all[i] * np.sqrt(dt) * Zm) 
    return S_all

# %%
T = 1
K = 99
S = 100
sigma = 0.2
r = 0.06

# %%
M=52
s_all = [GBM_Euler(T, K, S, sigma, r, M) for x in range(1000)]
s_all_exact = [GBM_exact(T, K, S, sigma, r, M)[0] for x in range(1000)]

# %%
arrays = [np.array(x) for x in s_all]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
arrays = [np.array(x) for x in s_all_exact]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
s_all_exact, Z_all = GBM_exact(T, K, S, sigma, r, M)
s_all = GBM_Euler(T, K, S, sigma, r, M, Z_all)

# %%
plt.plot(s_all_exact)

# %%
plt.plot(s_all)

# %%
def get_delta(S, K, r, sigma, tau):
    d1 = (math.log(S/K) + (r + 0.5 * sigma**2) * tau) / (sigma * math.sqrt(tau))
    return norm.cdf(d1)

def adjust_hedge(portfolio, delta, S):
    portfolio['stocks'] = delta

    
def simulate_hedge(T, K, S, sigma, delta_sigma, r, M, Z_all = None):
    # setup
    S_all = []
    S_all.append(S)
    delta_all = []
    dt = T/M
    tau = T
    # riskfree portfolio for a call option sells the call and buys the stock, right?
    portfolio = {}
    portfolio['stocks'] = get_delta(S, K, r, delta_sigma, tau)
    delta_all.append(portfolio['stocks'])
    
    # run the hedging simulation
    for i in range(M-1):
        if Z_all:
            Zm = Z_all[i]
        else:
            Zm = np.random.normal()
        S_all.append(S_all[i] + r* S_all[i] * dt + sigma * S_all[i] * np.sqrt(dt) * Zm) 
        tau -= dt
        
        delta = get_delta(S_all[-1], K, r, delta_sigma, tau)
        adjust_hedge(portfolio, delta, S_all[-1])
        delta_all.append(portfolio['stocks'])
    return delta_all

# %%
T = 1
K = 99
S = 100
sigma = 0.2
delta_sigma = 0.2
r = 0.06
M=365

# %%
delta= [simulate_hedge(T, K, S, sigma, delta_sigma, r, M) for x in range(100)]
delta_bigger = [simulate_hedge(T, K, S, sigma, 0.5, r, M) for x in range(100)]
delta_smaller = [simulate_hedge(T, K, S, sigma, 0.05, r, M) for x in range(100)]

# %%
arrays = [np.array(x) for x in delta]
plt.plot([np.mean(k) for k in zip(*arrays)])

arrays = [np.array(x) for x in delta_bigger]
plt.plot([np.mean(k) for k in zip(*arrays)])

arrays = [np.array(x) for x in delta_smaller]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
T = 1
K = 99
S = 100
sigma = 0.2
delta_sigma = 0.2
r = 0.06
M=52

# %%
delta= [simulate_hedge(T, K, S, sigma, delta_sigma, r, M) for x in range(100)]
delta_daily= [simulate_hedge(T, K, S, sigma, delta_sigma, r, 365) for x in range(100)]

# %%
arrays = [np.array(x) for x in delta]
plt.plot( np.linspace(0,365,52), [np.mean(k) for k in zip(*arrays)])

arrays = [np.array(x) for x in delta_daily]
plt.plot([np.mean(k) for k in zip(*arrays)])

# %%
def get_delta(S, K, r, sigma, tau):
    d1 = (math.log(S/K) + (r + 0.5 * sigma**2) * tau) / (sigma * math.sqrt(tau))
    return norm.cdf(d1)

def adjust_hedge(portfolio, delta, S):
    if portfolio['stocks'] < delta:
        portfolio['money'] -= (delta - portfolio['stocks']) * S
        portfolio['stocks'] = delta
    else:
        portfolio['money'] += (portfolio['stocks'] - delta) * S
        portfolio['stocks'] = delta

    
def Black_Scholes_Call(S, K, r, vol, tau):
    d1 = (np.log(S / K) + (r + ((vol**2)/2.)*tau)) / (vol*np.sqrt(tau))
    d2 = d1 - vol*np.sqrt(tau)

    V = S * norm.cdf(d1) - np.exp(-r*tau) * K * norm.cdf(d2)
    
    return V, norm.cdf(d1)
    
def simulate_hedge(T, K, S, sigma, delta_sigma, r, M, Z_all = None):
    # setup
    S_all = []
    S_all.append(S)
    delta_all = []
    dt = T/M
    tau = T
    # riskfree portfolio for a call option sells the call and buys the stock, right?
    portfolio = {}
    portfolio['stocks'] = get_delta(S, K, r, delta_sigma, tau)
    portfolio['call'] = -1
    initial_loan = S * portfolio['stocks'] - Black_Scholes_Call(S, K, r, delta_sigma, tau)[0]
    portfolio['money'] = 0
    delta_all.append(portfolio['stocks'])
    
    # run the hedging simulation
    for i in range(M-1):
        if Z_all:
            Zm = Z_all[i]
        else:
            Zm = np.random.normal()
        S_all.append(S_all[i] + r* S_all[i] * dt + sigma * S_all[i] * np.sqrt(dt) * Zm) 
        tau -= dt
        
        delta = get_delta(S_all[-1], K, r, delta_sigma, tau)
        adjust_hedge(portfolio, delta, S_all[-1])
        delta_all.append(portfolio['stocks'])
        
    # call gets excercised
    if S_all[-1] > K:
        portfolio['money'] -= (1 - portfolio['stocks']) * S_all[-1]
        portfolio['money'] += K 
        portfolio['stocks'] = 0
        portfolio['call'] = 0
    else:
        portfolio['money'] += portfolio['stocks'] * S_all[-1]
        portfolio['stocks'] = 0
        portfolio['call'] = 0
        
    portfolio['money'] -= initial_loan * math.e**r
    return portfolio['money']

# %%
T = 1
K = 99
S = 100
sigma = 0.01
delta_sigma = 0.2
r = 0.06
M=365

# %%
all_money = [simulate_hedge(T, K, S, sigma, delta_sigma, r, M) for x in range(100)]

# %%
np.mean(all_money)
# Out:
# 5.534399036563742
